# %%
#Reading excel file

import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
print(df.to_string())


#Reading Csv file

import pandas as pd
df = pd.read_csv("D:\Flavors.csv")
df

print()

#Reading json file


import pandas as pd
df = pd.read_json("D:\json_sample.json")
print(df)
# Out:
#      Plant Code            sku    MRP  Offer price
# 0          5030  8903287040139  50540        37905
# 1          4085  8903287040139  50540        37905
# 2          4065  8903287040139  50540        37905
# 3          3040  8903287040139  50540        37905
# 4          3010  8903287040139  50540        37905
# 5          5016  8903287040139  50540        37905
# 6          5010  8903287040139  50540        37905
# 7          3020  8903287040139  50540        37905
# 8          4025  8903287040139  50540        37905
# 9          3035  8903287040139  50540        37905
# 10         4030  8903287040139  50540        37905
# 11         3030  8903287040139  50540        37905
# 12         3000  8903287040139  50540        37905
# 13         2055  8903287040139  50540        37905
# 14         2054  8903287040139  50540        37905
# 15         2045  8903287040139  50540        37905
# 16         2050  8903287040139  50540        37905
# ...

# %%
#Some Operations on Cols

import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
df

#creating extra  cols using existing cols  
      
df["tot"] = df['MRP']+df['Offer price']
print(df)


#getting discount price

df["total"] = df['MRP'] - (df['MRP']*8/100)
print(df)


#getting discount percent column

df["dsc"] = (1-(df['Offer price']/df['MRP']))*100
print(df)


#getting saving ammount

df["sav amount"] = df['MRP']-df['Offer price']
print(df)
# Out:
#      Plant Code            sku    MRP  Offer price     tot
# 0          5030  8903287040139  50540        37905   88445
# 1          4085  8903287040139  50540        37905   88445
# 2          4065  8903287040139  50540        37905   88445
# 3          3040  8903287040139  50540        37905   88445
# 4          3010  8903287040139  50540        37905   88445
# ..          ...            ...    ...          ...     ...
# 825        4015  8903287002939  52990        49811  102801
# 826        4000  8903287002939  52990        49811  102801
# 827        4005  8903287002939  52990        49811  102801
# 828        4016  8903287002939  52990        49811  102801
# 829        4010  8903287002939  52990        49811  102801
#
# [830 rows x 5 columns]
#      Plant Code            sku    MRP  Offer price     tot    total
# 0          5030  8903287040139  50540        37905   88445  46496.8
# 1          4085  8903287040139  50540        37905   88445  46496.8
# ...

# %%
#to print all col 

print(df.columns)


#To get TOP 5 cols

df["sku"].head()

#to get unique values
df['sku'].unique()

#to get single cols
df.MRP
df["MRP"]

#to get 10 rows of sku

df.loc[0:10, ['sku']]


#to get multiple cols 


df[['sku', 'Plant Code']]

#to get cols from 0 to 10 of sku & offer price

df.loc[0:10 , 'sku' : 'Offer price']


#to get unique cols

df = df['sku'].unique()
df
# Out:
# Index(['Plant Code', 'sku', 'MRP', 'Offer price'], dtype='object')
#               sku    MRP  Offer price
# 0   8903287040139  50540        37905
# 1   8903287040139  50540        37905
# 2   8903287040139  50540        37905
# 3   8903287040139  50540        37905
# 4   8903287040139  50540        37905
# 5   8903287040139  50540        37905
# 6   8903287040139  50540        37905
# 7   8903287040139  50540        37905
# 8   8903287040139  50540        37905
# 9   8903287040139  50540        37905
# 10  8903287040139  50540        37905

# %%
#accessing rows


import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
df




#Selecting  single rows like here we r  accessing 2nd row

row = df.loc[2]
print(row)

#from 2 t0 10 rows multiple
row = df.loc[2:10]
print(row)


#rows from 0 t0 1 & column 2

df.iloc[[0, 1], 2]

#if u wnt rows from 0 to 1 & cols specific

df.loc[[0, 1], ['sku', 'MRP']]
# Out:
# Plant Code              4065
# sku            8903287040139
# MRP                    50540
# Offer price            37905
# Name: 2, dtype: int64
#     Plant Code            sku    MRP  Offer price
# 2         4065  8903287040139  50540        37905
# 3         3040  8903287040139  50540        37905
# 4         3010  8903287040139  50540        37905
# 5         5016  8903287040139  50540        37905
# 6         5010  8903287040139  50540        37905
# 7         3020  8903287040139  50540        37905
# 8         4025  8903287040139  50540        37905
# 9         3035  8903287040139  50540        37905
# 10        4030  8903287040139  50540        37905
# Empty DataFrame
# Columns: [Plant Code, sku, MRP, Offer price]
# Index: []

# %%
import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
df
#to get no.of cols &rows

print(df.shape)

#to get dtype
print(df.info())

#to get some nrml calculations

print(df.describe())


#to delete duplicates

df = df.drop_duplicates()
print(df.to_string())
# Out:
# (830, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Plant Code   830 non-null    int64
#  1   sku          830 non-null    int64
#  2   MRP          830 non-null    int64
#  3   Offer price  830 non-null    int64
# dtypes: int64(4)
# memory usage: 26.1 KB
# None
#         Plant Code           sku           MRP   Offer price
# count   830.000000  8.300000e+02    830.000000    830.000000
# mean   3500.122892  8.903287e+12  41000.216867  31461.506024
# std    1115.063326  1.416615e+04  10281.378471   9355.928192
# min    2005.000000  8.903287e+12  25290.000000  18145.000000
# 25%    2070.000000  8.903287e+12  34490.000000  24484.000000
# 50%    4005.000000  8.903287e+12  37990.000000  28493.000000
# 75%    4065.000000  8.903287e+12  50990.000000  38993.000000
# max    5040.000000  8.903287e+12  62990.000000  50392.000000
# ...

# %%
#Filtering


import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
df


#adding two cols in one col

df['actual price'] = df['MRP'].astype(str) + ' ' +df['Offer price'].astype(str)
print(df)




#Deleting single cols

df = df.drop(columns = "MRP")
df


#to delete multiple cols

df.drop(columns=['Plant Code','MRP'], inplace=True)
df
# Out:
#      Plant Code            sku    MRP  Offer price actual price
# 0          5030  8903287040139  50540        37905  50540 37905
# 1          4085  8903287040139  50540        37905  50540 37905
# 2          4065  8903287040139  50540        37905  50540 37905
# 3          3040  8903287040139  50540        37905  50540 37905
# 4          3010  8903287040139  50540        37905  50540 37905
# ..          ...            ...    ...          ...          ...
# 825        4015  8903287002939  52990        49811  52990 49811
# 826        4000  8903287002939  52990        49811  52990 49811
# 827        4005  8903287002939  52990        49811  52990 49811
# 828        4016  8903287002939  52990        49811  52990 49811
# 829        4010  8903287002939  52990        49811  52990 49811
#
# [830 rows x 5 columns]
#                sku  Offer price actual price
# 0    8903287040139        37905  50540 37905
# 1    8903287040139        37905  50540 37905
# ...

# %%
#Filtering


import pandas as pd
df = pd.read_csv("D:\Flavors.csv")
print(df)

filt = df['Base Flavor'].str.contains('Vanilla', na=False)
filt



#deleting single column

df = df.drop(columns = "Liked")
df

#deleting multiple cols

df.drop(columns=['Texture Rating','Flavor Rating'], inplace=True)
df


#deleting row
df.drop(index=4)


#deleting certin row

filt = df['Total Rating'] == '8.8'
df.drop(index=df[filt].index)
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3
# ...

# %%
import pandas as pd
df = pd.read_excel("C:\ex1-prices.xlsx")

#renaming one col name

df.rename(columns={'plant': 'plantCodes'}, inplace=True)
print(df['plantCodes'])



#renaming multiple col names


df.rename(columns={'plant': 'plantCodes', 'sku': 'SapCodes'}, inplace=True)


print(df)

# why im getting nan bcoz no value is yes or true so 

df['plantCodes'].map({'Yes': True, 'No': False})
print(df)


#to get all col names
df.columns
# Out:
# 0     4020.0
# 1     4015.0
# 2     4000.0
# 3     4005.0
# 4     4016.0
#        ...
# 72    4046.0
# 73    5024.0
# 74    4043.0
# 75    2011.0
# 76    4036.0
# Name: plantCodes, Length: 77, dtype: float64
#     plantCodes      SapCodes  store_id capacity                poe  \
# 0       4020.0  8.903287e+12       1.0      7kg  FL-FRONT LOADER-2
# 1       4015.0  8.903287e+12       1.0      7kg  FL-FRONT LOADER-2
# 2       4000.0  8.903287e+12       1.0      7kg  FL-FRONT LOADER-2
# 3       4005.0  8.903287e+12       1.0      7kg  FL-FRONT LOADER-2
# 4       4016.0  8.903287e+12       1.0      7kg  FL-FRONT LOADER-2
# ..         ...           ...       ...      ...                ...
# 72      4046.0  8.903287e+12       1.0      7kg    FL-TOP LOADER-2
# 73      5024.0  8.903287e+12       1.0      7kg    FL-TOP LOADER-2
# 74      4043.0  8.903287e+12       1.0      7kg    FL-TOP LOADER-2
# 75      2011.0  8.903287e+12       1.0      7kg    FL-TOP LOADER-2
# ...

# %%
#Sorting
import pandas as pd
df = pd.read_csv("D:\Flavors.csv")
print(df)

df.sort_values(by=['Base Flavor', 'Total Rating'], ascending=[True, False], inplace=True)
print(df[['Base Flavor', 'Total Rating']])

#if u want to print just 10 

#df[['Base Flavor', 'Total Rating']].head(10)


#u want some cols like ascending order

df['Total Rating'].nlargest(10)



#u want some cols like descending order

df['Total Rating'].nsmallest(10)
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3
#   Base Flavor  Total Rating
# ...

# %%
import pandas as pd
df = pd.read_csv("D:\Flavors.csv")

df.rename(columns={'Flavor': 'Flavor_Name', 'Liked': 'Loved'}, inplace=True)
df


df['Flavor_Name'].replace('Mint Chocolate Chip', 'Mint Chocolate', inplace=True)
df['Flavor_Name'].replace('Chocolte Fudge Brownie', 'Chocolate Brownie', inplace=True)
df
# Out:
#          Flavor_Name Base Flavor Loved  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate     Vanilla   Yes           10.0             8.0
# 1          Chocolate   Chocolate   Yes            8.8             7.6
# 2            Vanilla     Vanilla    No            4.7             5.0
# 3       Cookie Dough     Vanilla   Yes            6.9             6.5
# 4         Rocky Road   Chocolate   Yes            8.2             7.0
# 5          Pistachio     Vanilla    No            2.3             3.4
# 6        Cake Batter     Vanilla   Yes            6.5             6.0
# 7         Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolate Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
print(df.to_string())


df.sort_values(by=['MRP', 'Offer price'], ascending=[True, False], inplace=True)
print(df[['MRP', 'Offer price']])

#if u want to print just 10 

#df[['Base Flavor', 'Total Rating']].head(10)


#u want some cols like ascending order

df['MRP'].nlargest(100)



#u want some cols like descending order

df['Offer price'].nsmallest(100)
# Out:
#      Plant Code            sku    MRP  Offer price
# 0          5030  8903287040139  50540        37905
# 1          4085  8903287040139  50540        37905
# 2          4065  8903287040139  50540        37905
# 3          3040  8903287040139  50540        37905
# 4          3010  8903287040139  50540        37905
# 5          5016  8903287040139  50540        37905
# 6          5010  8903287040139  50540        37905
# 7          3020  8903287040139  50540        37905
# 8          4025  8903287040139  50540        37905
# 9          3035  8903287040139  50540        37905
# 10         4030  8903287040139  50540        37905
# 11         3030  8903287040139  50540        37905
# 12         3000  8903287040139  50540        37905
# 13         2055  8903287040139  50540        37905
# 14         2054  8903287040139  50540        37905
# 15         2045  8903287040139  50540        37905
# 16         2050  8903287040139  50540        37905
# ...

# %%
#Exporting 

import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")


# saving excel file into computer


df.to_excel('RegionPrice.xlsx')
print(df.to_excel)


#exporting to specific location



df.to_excel("D:\pp/RegionPrice.xlsx")
print(df)
# Out:
# <bound method NDFrame.to_excel of      Plant Code            sku    MRP  Offer price
# 0          5030  8903287040139  50540        37905
# 1          4085  8903287040139  50540        37905
# 2          4065  8903287040139  50540        37905
# 3          3040  8903287040139  50540        37905
# 4          3010  8903287040139  50540        37905
# ..          ...            ...    ...          ...
# 825        4015  8903287002939  52990        49811
# 826        4000  8903287002939  52990        49811
# 827        4005  8903287002939  52990        49811
# 828        4016  8903287002939  52990        49811
# 829        4010  8903287002939  52990        49811
#
# [830 rows x 4 columns]>
#      Plant Code            sku    MRP  Offer price
# 0          5030  8903287040139  50540        37905
# 1          4085  8903287040139  50540        37905
# 2          4065  8903287040139  50540        37905
# 3          3040  8903287040139  50540        37905
# ...

# %%
#Creating DataFrame Using Existing DataFrame

import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
print(df.to_string())

new_df = df[['sku', 'Offer price']]
print(new_df.to_string())
# Out:
#      Plant Code            sku    MRP  Offer price
# 0          5030  8903287040139  50540        37905
# 1          4085  8903287040139  50540        37905
# 2          4065  8903287040139  50540        37905
# 3          3040  8903287040139  50540        37905
# 4          3010  8903287040139  50540        37905
# 5          5016  8903287040139  50540        37905
# 6          5010  8903287040139  50540        37905
# 7          3020  8903287040139  50540        37905
# 8          4025  8903287040139  50540        37905
# 9          3035  8903287040139  50540        37905
# 10         4030  8903287040139  50540        37905
# 11         3030  8903287040139  50540        37905
# 12         3000  8903287040139  50540        37905
# 13         2055  8903287040139  50540        37905
# 14         2054  8903287040139  50540        37905
# 15         2045  8903287040139  50540        37905
# 16         2050  8903287040139  50540        37905
# ...

# %%
#Creating DataFrame Using Existing DataFrame for specific Sku

import pandas as pd
df = pd.read_excel("D:\Pan-india & TN  Region Price (1).xlsx")
print(df.to_string())


#if sku type is not str then convert into str

print(df['sku'].dtype)
df['sku'] = df['sku'].astype(str)
df


specific_sku = '8903287040337'
filtered_df = df.loc[df['sku'] == specific_sku, ['sku', 'Offer price']]
print(filtered_df)
# Out:
#      Plant Code            sku    MRP  Offer price
# 0          5030  8903287040139  50540        37905
# 1          4085  8903287040139  50540        37905
# 2          4065  8903287040139  50540        37905
# 3          3040  8903287040139  50540        37905
# 4          3010  8903287040139  50540        37905
# 5          5016  8903287040139  50540        37905
# 6          5010  8903287040139  50540        37905
# 7          3020  8903287040139  50540        37905
# 8          4025  8903287040139  50540        37905
# 9          3035  8903287040139  50540        37905
# 10         4030  8903287040139  50540        37905
# 11         3030  8903287040139  50540        37905
# 12         3000  8903287040139  50540        37905
# 13         2055  8903287040139  50540        37905
# 14         2054  8903287040139  50540        37905
# 15         2045  8903287040139  50540        37905
# 16         2050  8903287040139  50540        37905
# ...

# %%
#Exporting that file

specific_sku = '8903287040337'
filtered_df = df.loc[df['sku'] == specific_sku, ['sku', 'Offer price']]
print(filtered_df)


print()

filtered_df.to_excel('SingleSku.xlsx')
print(filtered_df.to_excel)



#exporting to specific location

filtered_df.to_excel("D:\pp/SingleSku.xlsx")
print(filtered_df.to_excel)
# Out:
#                sku  Offer price
# 224  8903287040337        25868
# 225  8903287040337        25868
# 226  8903287040337        25868
# 227  8903287040337        25868
# 228  8903287040337        25868
# 229  8903287040337        25868
# 230  8903287040337        25868
# 231  8903287040337        25868
# 232  8903287040337        25868
# 233  8903287040337        25868
# 234  8903287040337        25868
# 235  8903287040337        25868
# 236  8903287040337        25868
# 237  8903287040337        25868
# 238  8903287040337        25868
# 239  8903287040337        25868
# 240  8903287040337        25868
# 241  8903287040337        25868
# 242  8903287040337        25868
# 243  8903287040337        25868
# 244  8903287040337        25868
# 245  8903287040337        25868
# 246  8903287040337        25868
# 247  8903287040337        25868
# 248  8903287040337        25868
# 249  8903287040337        25868
# 250  8903287040337        25868
# 251  8903287040337        25868
# ...

# %%
#loading api


import pandas as pd
import requests

# here endpoint is match ID

url = "https://api.opendota.com/api/matches/3703866531"  # Replace with a valid match ID

# Make the GET request

response = requests.get(url)
print(response)


if response.status_code == 200:
    data = response.json()  # Parse the JSON response
    print("Match Details:")# printing response code
    
    print(data)  # Print the match data
else:
    print(f"Failed to fetch data. HTTP Status Code: {response.status_code}")
# Out:
# <Response [200]>
# Match Details:
# ...

# %%
import pandas as pd
import requests




url = "https://mcstaging.ifbappliances.com/rest/V1/orders?searchCriteria%5Bfilter_groups%5D%5B0%5D%5Bfilters%5D%5B0%5D%5Bfield%5D=increment_id&searchCriteria%5Bfilter_groups%5D%5B0%5D%5Bfilters%5D%5B0%5D%5Bcondition_type%5D=eq&searchCriteria%5Bfilter_groups%5D%5B0%5D%5Bfilters%5D%5B0%5D%5Bvalue%5D=1000506372&searchCriteria%5BsortOrders%5D%5B0%5D%5Bfield%5D=increment_id"
api_key = "lg09zhe5od5dzkmeb03lj2mxhbbo2k0p"

# Set up headers with the API key 

headers = {
    "Authorization": f"Bearer {api_key}",  # For Bearer Token-based APIs
                                            # For APIs that pass keys as headers
}

#  Make the API request

response = requests.get(url, headers=headers)

# Check if the request was successful

if response.status_code == 200:
   
    data = response.json() # Parse the JSON response
    print(response.status_code)
    print(data)
else:
    print(f"Failed to fetch data: {response.status_code}, {response.text}")
# Out:
# 200
# ...

# %%
#Getting items data

import json
import pandas as pd

# Load the JSON data

with open('C:\Data.json.json', "r") as file:
    data = json.load(file)
items = data["items"]
print(items)
# Out:
# [{'base_currency_code': 'INR', 'base_discount_amount': 0, 'base_grand_total': 40679, 'base_discount_tax_compensation_amount': 0, 'base_shipping_amount': 0, 'base_shipping_discount_amount': 0, 'base_shipping_discount_tax_compensation_amnt': 0, 'base_shipping_incl_tax': 0, 'base_shipping_tax_amount': 0, 'base_subtotal': 40679, 'base_subtotal_incl_tax': 40679, 'base_tax_amount': 0, 'base_total_due': 40679, 'base_to_global_rate': 1, 'base_to_order_rate': 1, 'billing_address_id': 1151912, 'created_at': '2024-04-02 10:11:32', 'customer_email': 'mohammad_rahman@ifbglobal.com', 'customer_firstname': 'rahman', 'customer_gender': 1, 'customer_group_id': 1, 'customer_id': 2602838, 'customer_is_guest': 0, 'customer_lastname': 'mohammad', 'customer_note_notify': 1, 'discount_amount': 0, 'entity_id': 576176, 'global_currency_code': 'INR', 'grand_total': 40679, 'discount_tax_compensation_amount': 0, 'increment_id': '1000506372', 'is_virtual': 0, 'order_currency_code': 'INR', 'protect_code': 'b03288
# ...

# %%
#items.columns we r not getting here bcoz its not dataframe
#print(items[:2])

#we need to convert the list to dataFrame
items = pd.DataFrame(items)

#to know the type of items

print(type(items))

# Now u Check the columns names
print(items.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['base_currency_code', 'base_discount_amount', 'base_grand_total',
#        'base_discount_tax_compensation_amount', 'base_shipping_amount',
#        'base_shipping_discount_amount',
#        'base_shipping_discount_tax_compensation_amnt',
#        'base_shipping_incl_tax', 'base_shipping_tax_amount', 'base_subtotal',
#        'base_subtotal_incl_tax', 'base_tax_amount', 'base_total_due',
#        'base_to_global_rate', 'base_to_order_rate', 'billing_address_id',
#        'created_at', 'customer_email', 'customer_firstname', 'customer_gender',
#        'customer_group_id', 'customer_id', 'customer_is_guest',
#        'customer_lastname', 'customer_note_notify', 'discount_amount',
#        'entity_id', 'global_currency_code', 'grand_total',
#        'discount_tax_compensation_amount', 'increment_id', 'is_virtual',
#        'order_currency_code', 'protect_code', 'quote_id', 'remote_ip',
# ...

# %%
df_summary = items[["items"]]
print(df_summary.to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# Extract nested 'items' from the main data

products = [order["items"] for order in items]

#  the nested 'items' for all orders

df_products = pd.json_normalize(products[0])  # Adjust index for a specific order

print(df_products[["sku", "name", "price", "qty_ordered", "row_total"]])
# Out:
#              sku                name  price  qty_ordered  row_total
# 0  8903287024788  Senator WSS STEAM   40319            1      40319
# 1  8903287080333   Fluff Front Load     360            1        360

# %%
df_summary = items[["billing_address"]]
print(df_summary.to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                         billing_address
# 0  {'address_type': 'billing', 'city': 'goa', 'country_id': 'IN', 'customer_address_id': 1773407, 'email': 'mohammad_rahman@ifbglobal.com', 'entity_id': 1151912, 'firstname': 'rahman', 'lastname': 'mohammad', 'parent_id': 576176, 'postcode': '403722', 'region': 'Telangana', 'region_code': 'Telangana', 'region_id': 516, 'street': ['goa', 'verna'], 'telephone': '8624009660'}

# %%
# Extract billing addresses
billing_addresses = [order["billing_address"] for order in items]

# Flatten billing address data
df_billing = pd.json_normalize(billing_addresses)

print(df_billing[["firstname", "lastname", "city", "region", "telephone"]])
# Out:
#   firstname  lastname city     region   telephone
# 0    rahman  mohammad  goa  Telangana  8624009660

# %%
df_summary = items[["increment_id", "customer_email", "grand_total", "status"]]
print(df_summary)
# Out:
#   increment_id                 customer_email  grand_total      status
# 0   1000506372  mohammad_rahman@ifbglobal.com        40679  processing

# %%
df_summary = items[["discount_tax_compensation_amount", "total_item_count", "base_total_due", "total_due"]]
print(df_summary.to_string())
# Out:
#    discount_tax_compensation_amount  total_item_count  base_total_due  total_due
# 0                                 0                 2           40679      40679

# %%
df_summary = items[["discount_tax_compensation_amount", "discount_amount", "shipping_description", "shipping_discount_amount"]]
print(df_summary.to_string())
# Out:
#    discount_tax_compensation_amount  discount_amount  shipping_description  shipping_discount_amount
# 0                                 0                0  Free Shipping - Free                         0

# %%
df_summary = items[["customer_firstname", "customer_id", "customer_email", "customer_gender"]]
print(df_summary.to_string())
# Out:
#   customer_firstname  customer_id                 customer_email  customer_gender
# 0             rahman      2602838  mohammad_rahman@ifbglobal.com                1

# %%
#exporting  data in api into excel format


df_summary = items[['base_currency_code','base_discount_amount', 'base_grand_total',
       'base_discount_tax_compensation_amount', 'base_shipping_amount',
       'base_shipping_discount_amount',
       'base_shipping_discount_tax_compensation_amnt',
       'base_shipping_incl_tax', 'base_shipping_tax_amount', 'base_subtotal',
       'base_subtotal_incl_tax', 'base_tax_amount', 'base_total_due',
       'base_to_global_rate', 'base_to_order_rate', 'billing_address_id',
       'created_at', 'customer_email', 'customer_firstname', 'customer_gender',
       'customer_group_id', 'customer_id', 'customer_is_guest',
       'customer_lastname', 'customer_note_notify', 'discount_amount',
       'entity_id', 'global_currency_code', 'grand_total',
       'discount_tax_compensation_amount', 'increment_id', 'is_virtual',
       'order_currency_code', 'protect_code', 'quote_id', 'remote_ip',
       'shipping_amount', 'shipping_description', 'shipping_discount_amount',
       'shipping_discount_tax_compensation_amount', 'shipping_incl_tax',
       'shipping_tax_amount', 'state', 'status', 'store_currency_code',
       'store_id', 'store_name', 'store_to_base_rate', 'store_to_order_rate',
       'subtotal', 'subtotal_incl_tax', 'tax_amount', 'total_due',
       'total_item_count', 'total_qty_ordered', 'updated_at', 'weight',
       'items', 'billing_address', 'payment', 'status_histories',
       'extension_attributes']]
print(df_summary.to_string())


df_summary.to_excel("itemslnf.xlsx")
print(df_summary.to_excel)

df_summary.to_excel("D:\pp/itemsinf.xlsx")
print(df_summary.to_excel)
# Out:
#   base_currency_code  base_discount_amount  base_grand_total  base_discount_tax_compensation_amount  base_shipping_amount  base_shipping_discount_amount  base_shipping_discount_tax_compensation_amnt  base_shipping_incl_tax  base_shipping_tax_amount  base_subtotal  base_subtotal_incl_tax  base_tax_amount  base_total_due  base_to_global_rate  base_to_order_rate  billing_address_id           created_at                 customer_email customer_firstname  customer_gender  customer_group_id  customer_id  customer_is_guest customer_lastname  customer_note_notify  discount_amount  entity_id global_currency_code  grand_total  discount_tax_compensation_amount increment_id  is_virtual order_currency_code                      protect_code  quote_id       remote_ip  shipping_amount  shipping_description  shipping_discount_amount  shipping_discount_tax_compensation_amount  shipping_incl_tax  shipping_tax_amount       state      status store_currency_code  store_id                                   
# ...

# %%
#exporting some data in api into excel format

print(type(items))


df_products = pd.json_normalize(products[0])  
print(df_products[["sku", "name", "price", "qty_ordered", "row_total"]])

df_products.to_excel("itemslnfo.xlsx")
print(df_products.to_excel)

df_products.to_excel("D:\pp/itemsinfo.xlsx")
print(df_products.to_excel)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#              sku                name  price  qty_ordered  row_total
# 0  8903287024788  Senator WSS STEAM   40319            1      40319
# 1  8903287080333   Fluff Front Load     360            1        360
# <bound method NDFrame.to_excel of    amount_refunded applied_rule_ids  base_amount_refunded  \
# 0                0            28886                     0
# 1                0            28886                     0
#
#    base_discount_amount  base_discount_invoiced  \
# 0                     0                       0
# 1                     0                       0
#
#    base_discount_tax_compensation_amount  base_original_price  base_price  \
# 0                                      0                40319       40319
# 1                                      0                  360         360
#
#    base_price_incl_tax  base_row_invoiced  ...  \
# 0                40319                  0  ...
# ...

# %%
import pandas as pd

df_summary = items[["status_histories"]]
print(df_summary.to_string())
print(type(df_summary))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           status_histories
# 0  [{'comment': 'mode = NB
#  <br />status = success
#  <br />unmappedstatus = captured
#  <br />txnid = 1000506372
#  <br />amount = 40679.00
#  <br />net_amount_debit = 40679
#  <br />PG_TYPE = NB-PG
#  <br />bank_ref_num = 507ea7b6-3420-4203-befd-94f3704e3ccd
# ...

# %%
#payment
df_summary = items[["payment"]]
print(df_summary.to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                   payment
# 0  {'account_status': None, 'additional_information': ['12910190', 'Payu'], 'amount_ordered': 40679, 'base_amount_ordered': 40679, 'base_shipping_amount': 0, 'cc_exp_year': '0', 'cc_last4': None, 'cc_number_enc': '1:3:jiaC9Iq8GZadwS1frjgVwYE9TGPAucfTl2a6Dw==', 'cc_ss_start_month': '0', 'cc_ss_start_year': '0', 'entity_id': 575975, 'method': 'payu', 'parent_id': 576176, 'shipping_amount': 0}

# %%
for payment in items:
    print(type(payment))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
